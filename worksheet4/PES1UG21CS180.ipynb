# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats
import statsmodels.api as sm
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.formula.api import ols
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 6>()
#       4 import seaborn as sns
#       5 import scipy.stats as stats
# ----> 6 import statsmodels.api as sm
#       7 from statsmodels.stats.multicomp import pairwise_tukeyhsd
#       8 from statsmodels.formula.api import ols
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
df = pd.read_csv('pet_training.csv')
df
# Out:
#     Pet Treat Task  ResponseTime
# 0     1     I    A      0.508638
# 1     2     I    B      0.086186
# 2     3     I    C      0.366532
# 3     4     I    D      0.346787
# 4     5     I    A      0.346787
# 5     6     I    B      0.041393
# 6     7     I    C      0.346787
# 7     8     I    D      0.148742
# 8     9     I    A      0.337242
# 9    10     I    B      0.055517
# 10   11     I    C      0.200659
# 11   12     I    D      0.180456
# 12   13     I    A      0.366532
# 13   14     I    B      0.142668
# 14   15     I    C      0.119186
# 15   16     I    D      0.207608
# 16   17    II    A      0.443697
# 17   18    II    B      0.036212
# 18   19    II    C      0.356547
# 19   20    II    D      0.301030
# 20   21    II    A      0.537602
# 21   22    II    B      0.214670
# 22   23    II    C      0.455932
# 23   24    II    D      0.008600
# 24   25    II    A      0.397940
# 25   26    II    B      0.309804
# 26   27    II    C      0.508638
# 27   28    II    D      0.148742
# 28   29    II    A      0.638272
# 29   30    II    B      0.093422
# 30   31    II    C      0.397940
# 31   32    II    D      0.420216
# 32   33   III    A      0.657577
# 33   34   III    B      0.522879
# 34   35   III    C      0.638272
# 35   36   III    D      0.522879
# 36   37   III    A      0.677781
# 37   38   III    B      0.431798
# 38   39   III    C      0.602060
# 39   40   III    D      0.443697
# 40   41   III    A      0.744727
# 41   42   III    B      0.420216
# 42   43   III    C      0.619789
# 43   44   III    D      0.508638
# 44   45   III    A      0.638272
# 45   46   III    B      0.537602
# 46   47   III    C      0.657577
# 47   48   III    D      0.481486

# %%
group = df.groupby('Task')['ResponseTime'].mean()
group
# Out:
# Task
# A    0.524589
# B    0.241031
# C    0.439160
# D    0.309907
# Name: ResponseTime, dtype: float64

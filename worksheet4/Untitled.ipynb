# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
df = pd.read_csv('pet_training.csv')

# %%
df
# Out:
#     Pet Treat Task  ResponseTime
# 0     1     I    A      0.508638
# 1     2     I    B      0.086186
# 2     3     I    C      0.366532
# 3     4     I    D      0.346787
# 4     5     I    A      0.346787
# 5     6     I    B      0.041393
# 6     7     I    C      0.346787
# 7     8     I    D      0.148742
# 8     9     I    A      0.337242
# 9    10     I    B      0.055517
# 10   11     I    C      0.200659
# 11   12     I    D      0.180456
# 12   13     I    A      0.366532
# 13   14     I    B      0.142668
# 14   15     I    C      0.119186
# 15   16     I    D      0.207608
# 16   17    II    A      0.443697
# 17   18    II    B      0.036212
# 18   19    II    C      0.356547
# 19   20    II    D      0.301030
# 20   21    II    A      0.537602
# 21   22    II    B      0.214670
# 22   23    II    C      0.455932
# 23   24    II    D      0.008600
# 24   25    II    A      0.397940
# 25   26    II    B      0.309804
# 26   27    II    C      0.508638
# ...

# %%
# Out:
# Task  ResponseTime  ResponseTime
# A     0.337242      0.337242        1
#       0.346787      0.346787        1
#       0.366532      0.366532        1
#       0.397940      0.397940        1
#       0.443697      0.443697        1
#       0.508638      0.508638        1
#       0.537602      0.537602        1
#       0.638272      0.638272        2
#       0.657577      0.657577        1
#       0.677781      0.677781        1
#       0.744727      0.744727        1
# B     0.036212      0.036212        1
#       0.041393      0.041393        1
#       0.055517      0.055517        1
#       0.086186      0.086186        1
#       0.093422      0.093422        1
#       0.142668      0.142668        1
#       0.214670      0.214670        1
#       0.309804      0.309804        1
#       0.420216      0.420216        1
#       0.431798      0.431798        1
#       0.522879      0.522879        1
#       0.537602      0.537602        1
# C     0.119186      0.119186        1
# ...
